# %%
import nltk
import spacy
import csv
import torch
from lm_scorer.models.auto import AutoLMScorer
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-45-9b93a024d798> in <module>
#       3 import csv
#       4 import torch
# ----> 5 from lm_scorer.models.auto import AutoLMScorer
#
# ~/anaconda3/lib/python3.6/site-packages/lm_scorer/models/auto.py in <module>
#       4
#       5 from .abc.base import LMScorer
# ----> 6 from .gpt2 import GPT2LMScorer
#       7
#       8
#
# ~/anaconda3/lib/python3.6/site-packages/lm_scorer/models/gpt2.py in <module>
#       3
#       4 import torch
# ----> 5 from transformers import AutoTokenizer, GPT2LMHeadModel
#       6 from transformers import GPT2_PRETRAINED_CONFIG_ARCHIVE_MAP
#       7 from transformers.tokenization_utils import BatchEncoding
#
# ImportError: cannot import name 'AutoTokenizer'

# %%
nlp = spacy.load('en')

# %%
# texts = ["One document.", "...", "Lots of documents"]
# for doc in nlp.pipe(texts, batch_size=50):
#     assert doc.is_parsed

# doc = nlp.make_doc(texts)
# gold = GoldParse(doc, entities=entity_offsets)
# nlp.update([doc], [gold], drop=0.5, sgd=optimizer)
# scorer = nlp.evaluate(gold, verbose=True)
# print(scorer.scores)

# %%
from transformers import AutoTokenizer
import lm_scorer.models.auto
# from lm_scorer.models.auto import AutoLMScorer
# scorer = AutoLMScorer.from_pretrained("gpt2-large")

# def score(sentence):
#     return scorer.sentence_score(sentence)
# score('good luck')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-35-d71816103c7e> in <module>
# ----> 1 from transformers import AutoTokenizer
#       2 import lm_scorer.models.auto
#       3 # from lm_scorer.models.auto import AutoLMScorer
#       4 # scorer = AutoLMScorer.from_pretrained("gpt2-large")
#       5
#
# ImportError: cannot import name 'AutoTokenizer'

# %%
# Out:
# ['<mediawiki xmlns="http://www.mediawiki.org/xml/export-0.3/" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:schemaLocation="http://www.mediawiki.org/xml/export-0.3/ http://www.mediawiki.org/xml/export-0.3.xsd" version="0.3" xml:lang="en">\n',
#  '  <siteinfo>\n',
#  '    <sitename>Wikipedia</sitename>\n',
#  '    <base>http://en.wikipedia.org/wiki/Main_Page</base>\n',
#  '    <generator>MediaWiki 1.6alpha</generator>\n',
#  '    <case>first-letter</case>\n',
#  '      <namespaces>\n',
#  '      <namespace key="-2">Media</namespace>\n',
#  '      <namespace key="-1">Special</namespace>\n',
#  '      <namespace key="0" />\n',
#  '      <namespace key="1">Talk</namespace>\n',
#  '      <namespace key="2">User</namespace>\n',
#  '      <namespace key="3">User talk</namespace>\n',
#  '      <namespace key="4">Wikipedia</namespace>\n',
#  '      <namespace key="5">Wikipedia talk</namespace>\n',
#  '      <namespace key="6">Image</namespace>\n',
# ...

# %%
with open('Fake.csv') as csv_fake:
    reader = csv.DictReader
